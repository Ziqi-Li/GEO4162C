# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziqi-Li/GEO4162C/blob/fall-24/notebooks/Optimization_nutrition_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Linear Programming Example
#
# **Problem Statement:**
#
# A fitness person needs to buy two kinds of foods A and B. It is known that the food contains nutritional ingredients 1, 2, and 3 and the daily necessary amount of the three ingredients is shown in Table 2. How much should he buy each day? Food A and food B, which minimizes the total cost while satisfying the requirements?
#
#
#   Nutrition Info
#
# |          | A     | B    | Minimum daily needed  |
# | -------- | ----- | ---- | -------------------- |
# | N1    | 10mg    | 4mg    | 20mg                 |
# | N2    | 5mg     | 5mg    | 20mg                 |
# | N3    | 2mg     | 6mg    | 12mg                 |
# | Price | 2 dollars  | 5 dollars  |                      |

# %% [markdown]
# **Decision variables:**
# x1 and x2 are amount of A and B he needs to buy.
#
# **Objective function:**
# Minimizing the total cost: z = 2x1 + 5x2
#
#
# **Constraints:**
# \begin{equation}
# \begin{cases}
# 10x_1+4x_2\geq20&\\\
# 5x_1+5x_2\geq20&\\\
# 2x_1+6x_2\geq12&\\\
# x_1\geq0,x_2\geq0
# \end{cases}
# \end{equation}

# %% [markdown]
# Install the `pulp` package.

# %%
pip install -q pulp
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 20.9 MB/s eta 0:00:00

# %%
from pulp import *

# %%
#Declare decision variables
#Setting up Lower bound to be 0 and make them integer,
#which means the decision variable will be a positive whole number.
x1 = LpVariable("x1", lowBound=0,cat='Integer')
x2 = LpVariable("x2", lowBound=0,cat='Integer')

# %%
#Declare a minimization problem
#You will need to change to LpMaximize, if it is a maximization problem.
prob = LpProblem("Nutrition", LpMinimize)

# %%
#Objective function
prob += 2*x1 + 5*x2

# %%
#Add constraints
prob += 10*x1 + 4*x2 >= 20
prob += 5*x1 + 5*x2 >= 20
prob += 2*x1 + 6*x2 >= 12

# %%
#Solve the problem
prob.solve()

print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %% [markdown]
# If sucessful, the status should be `Optimal`.

# %%
# The minimized objective fuction
print("Objective: ",value(prob.objective), "dollars")
# Out:
# Objective:  11.0 dollars

# %%
print("The optimal amount to buy A is:", value(x1))
# Out:
# The optimal amount to buy A is: 3.0

# %%
print("The optimal amount to buy B is:", value(x2))
# Out:
# The optimal amount to buy B is: 1.0
