# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziqi-Li/GEO4162C/blob/fall-24/assignments/Assignment_6_Instruction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 6
#
# **Due date/time:** Nov 26 Tuesday 23:59pm
#
# **Instruction**: Make a copy of this notebook and read through the question and description. Write down code/text to perform the analysis.
#
# **Submission**: After you finish working on this notebook, click File->Download->Download .ipynb
#
# Please submit a notebook named A6_your_name.ipynb on Canvas.

# %%
pip install -q pulp
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 43.9 MB/s eta 0:00:00

# %% [markdown]
# ### Question
#
# Choose an appropriate spatial optimization technique to solve the below problem.
#
# **Problem**: Suppose the city is planning **5** farmers markets, where should they put the markets so to minimize the total distance travelled to these locations over the population.
#
# You are given some code to fetch the data for leon county and census tract level population.
#
#
# Replicate what we did with the [Florida example](https://github.com/Ziqi-Li/GEO4162C/blob/fall-24/notebooks/Spatial_optimization_p_median.ipynb), using the column *total_population* as the demand along with the distance between census tracts to solve this problem. There are 68 census tracts in Leon.
#
#
# Along with the code, also report these in your notebook:
# - Which optimization method should be used? (2pts)
# - Where (which census tract) should we place the farmer's markets? (5pts)
# - Map the location of the farmer's markets on top of the population map, similar to the in-class example. (3pts)

# %%
import geopandas as gpd
import pulp

# %%
leon_tract = gpd.read_file("https://raw.githubusercontent.com/Ziqi-Li/GEO4162C/refs/heads/fall-24/data/leon_population.geojson")

# %%
leon_tract.head()
# Out:
#                                        NAME  total_population state county  \
# 0  Census Tract 23.03, Leon County, Florida            4205.0    12    073
# 1  Census Tract 11.02, Leon County, Florida            2314.0    12    073
# 2  Census Tract 16.01, Leon County, Florida            5238.0    12    073
# 3  Census Tract 16.02, Leon County, Florida            3153.0    12    073
# 4     Census Tract 17, Leon County, Florida            7354.0    12    073
#
#     tract                                           geometry
# 0  002303  POLYGON ((-84.36322 30.4856, -84.36322 30.4849...
# 1  001102  POLYGON ((-84.30793 30.40409, -84.30762 30.404...
# 2  001601  POLYGON ((-84.27725 30.49317, -84.27725 30.492...
# 3  001602  POLYGON ((-84.27736 30.50531, -84.27736 30.504...
# 4  001700  POLYGON ((-84.27725 30.49245, -84.27726 30.492...

# %%
leon_tract.plot()
# Out:
# <Axes: >

# %% [markdown]
# Please go from here.
